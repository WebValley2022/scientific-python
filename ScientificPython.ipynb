# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
pokemons = pd.read_csv(
    "https://raw.githubusercontent.com/WebValley2022/python-programming/main/pokemon.csv"
)

# %%
# what's `pokemons` ?
type(pokemons)
# Out:
# pandas.core.frame.DataFrame

# %%
pokemons
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pokemons.Name
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
len(pokemons['Type 1'].unique()), pokemons['Type 1'].unique()
# Out:
# (18,
#  array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#         'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#         'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object))

# %%
type(pokemons['Type 1'].unique())
# Out:
# numpy.ndarray

# %%
pokemons.value_counts("Type 1")
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ghost        32
# Ground       32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# dtype: int64

# %%
pokemons.value_counts("Type 2")
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Rock        14
# Water       14
# Ice         14
# Ghost       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# dtype: int64

# %%
# how many pokemons there are for each generation?
pokemons.value_counts("Generation")
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# dtype: int64

# %%
# and how many Legendary pokemons for each generation?
# hint: select only some of the rows

pokemons[pokemons.Legendary == True].value_counts('Generation')
# Out:
# Generation
# 3    18
# 5    15
# 4    13
# 6     8
# 1     6
# 2     5
# dtype: int64

# %%
pokemons[pokemons['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2  Total   HP  Attack  \
# 4      4                 Charmander   Fire       NaN    309   39      52
# 5      5                 Charmeleon   Fire       NaN    405   58      64
# 6      6                  Charizard   Fire    Flying    534   78      84
# 7      6  CharizardMega Charizard X   Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y   Fire    Flying    634   78     104
# 42    37                     Vulpix   Fire       NaN    299   38      41
# 43    38                  Ninetales   Fire       NaN    505   73      76
# 63    58                  Growlithe   Fire       NaN    350   55      70
# 64    59                   Arcanine   Fire       NaN    555   90     110
# 83    77                     Ponyta   Fire       NaN    410   50      85
# 84    78                   Rapidash   Fire       NaN    500   65     100
# 135  126                     Magmar   Fire       NaN    495   65      95
# ...

# %%
# what's the average HP for each pokemon type?
pokemons.groupby(["Type 1", "Type 2"])['HP'].mean().sort_values()
# Out:
# Type 1   Type 2
# Bug      Ghost         1.000000
# Poison   Bug          40.000000
# Bug      Water        40.000000
# Psychic  Fairy        43.666667
# Bug      Ground       45.500000
#                         ...
# Ground   Electric    109.000000
#          Steel       110.000000
# Ghost    Flying      120.000000
# Dragon   Ice         125.000000
# Ghost    Dragon      150.000000
# Name: HP, Length: 136, dtype: float64

# %%
from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(10, 10))

sns.scatterplot(
    x="HP",
    y="Defense",
    data=pokemons,
    hue="Legendary",
    ax=ax
)
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Defense'>

# %%
pokemons[
    (pokemons.Legendary)
    & (pokemons.HP < 70)
    & (pokemons.Defense < 50)
]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 429      180       20    150           3       True

# %%
columns = [
    # "Type 1", 
    "Total",
    "HP", 
    "Attack",
    "Defense",
    "Sp. Atk",
    "Sp. Def",
    "Speed",
    "Generation"
]

# %%
sns.pairplot(
    data=pokemons[columns]
)

# %%
fig, ax = plt.subplots(figsize=(20, 5))
sns.boxplot(
    x="Type 1",
    y="Total",
    data=pokemons,
    ax=ax
)
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Total'>

# %%
fig, ax = plt.subplots(figsize=(20, 5))
sns.boxplot(
    x="Type 1",
    y="Total",
    data=pokemons,
    ax=ax
)
# Out:
# <AxesSubplot:xlabel='Type 1', ylabel='Total'>
